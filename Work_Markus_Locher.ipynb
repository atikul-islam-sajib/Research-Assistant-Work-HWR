# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/importances.csv')

# %%
df.head()
# Out:
#       MDI_0     MDI_1     MDI_2     MDI_3     MDI_4  relevance  \
# 0  0.587667  0.019302  0.056773  0.098600  0.237659          0
# 1  0.325005  0.051576  0.116466  0.104369  0.402584          0
# 2  0.318846  0.075423  0.112668  0.098629  0.394433          0
# 3  0.461039  0.024897  0.088969  0.164386  0.260708          0
# 4  0.447429  0.027610  0.082386  0.091690  0.350884          0
#
#              shrink_mode  lambda  replication
# 0                     hs   100.0            0
# 1             hs_entropy   100.0            0
# 2     hs_log_cardinality   100.0            0
# 3         hs_permutation    10.0            0
# 4  hs_global_permutation   100.0            0

# %%
df.columns
# Out:
# Index(['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4', 'relevance', 'shrink_mode',
#        'lambda', 'replication'],
#       dtype='object')

# %%
df.loc[:, 'shrink_mode'].value_counts()
# Out:
# hs                       640
# hs_entropy               640
# hs_log_cardinality       640
# hs_permutation           640
# hs_global_permutation    640
# Name: shrink_mode, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
def check(group):
    # Extract the first 5 columns as 'new' based on your requirement
    new = group[['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4']]

    # Create a boxplot for 'MDI_0' within the group
    sns.boxplot(data=new, x='MDI_0')
    plt.title(f'Boxplot of MDI_0 for group {group.name}')  # Include group name in title
    plt.show()

# Group by 'relevance' and 'shrink_mode', and apply the check function to each group
grouped = df.groupby(['relevance', 'shrink_mode'])
grouped.apply(check)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Create a boxplot using Seaborn with 'MDI' on the x-axis and 'value' on the y-axis
plt.figure(figsize=(12, 8))  # Adjust the figure size if needed
sns.boxplot(x='MDI', y='value', data=melted_df)
plt.title('Boxplot of MDI Values')
plt.xlabel('MDI')
plt.ylabel('Value')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Create a boxplot using Seaborn with 'MDI' on the x-axis, 'value' on the y-axis, and 'shrink_mode' as the hue
plt.figure(figsize=(12, 8))  # Adjust the figure size if needed
sns.boxplot(x='MDI', y='value', hue='shrink_mode', data=melted_df)
plt.title('Boxplot of MDI Values by Shrink Mode')
plt.xlabel('MDI')
plt.ylabel('Value')
plt.legend(title='Shrink Mode')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Create a grid of boxplots for each 'relevance' value
plt.figure(figsize=(16, 8))  # Adjust the figure size if needed

# Using facet_grid to create separate boxplots for each 'relevance' value
g = sns.FacetGrid(data=melted_df, col='relevance', sharey=True, height=5)
g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode')
g.set_axis_labels('MDI', 'Value')

# Customize the legend
g.add_legend(title='Shrink Mode')

plt.suptitle('Boxplots of MDI Values by Shrink Mode and Relevance', y=1.02)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Create a grid of boxplots for each 'relevance' value
plt.figure(figsize=(16, 8))  # Adjust the figure size if needed

# Using facet_grid to create separate boxplots for each 'relevance' value
g = sns.FacetGrid(data=melted_df, col='relevance', sharey=True, height=5)

# Define the boxplot
g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode')

# Customize plot appearance
g.set_axis_labels('MDI', 'Value')

# Customize the legend
g.add_legend(title='Shrink Mode')

# Add a title
plt.suptitle('Boxplots of MDI Values by Shrink Mode and Relevance', y=1.02)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Create a grid of boxplots for each 'relevance' value
plt.figure(figsize=(16, 8))  # Adjust the figure size if needed

# Using facet_grid to create separate boxplots for each 'relevance' value
g = sns.FacetGrid(data=melted_df, col='relevance', sharey=True, height=5)

# Define the boxplot and set the order of 'shrink_mode' values in the legend
g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes)

# Customize plot appearance
g.set_axis_labels('MDI', 'Value')

# Customize the legend
g.add_legend(title='Shrink Mode')

# Add a title
plt.suptitle('Boxplots of MDI Values by Shrink Mode and Relevance', y=1.02)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Create a grid of boxplots for each 'relevance' value
plt.figure(figsize=(16, 8))  # Adjust the figure size if needed

# Using facet_grid to create separate boxplots for each 'relevance' value
g = sns.FacetGrid(data=melted_df, col='relevance', sharey=True, height=5)

# Define the boxplot with 'value' on the y-axis and 'MDI' on the x-axis
g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes)

# Customize plot appearance
g.set_axis_labels('MDI', 'Value')

# Customize the legend
g.add_legend(title='Shrink Mode')

# Add a title
plt.suptitle('Boxplots of MDI Values by Shrink Mode and Relevance', y=1.02)

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Iterate through unique 'relevance' values and create diagrams
for relevance_value in melted_df['relevance'].unique():
    # Filter the data for the current 'relevance' value
    subset_df = melted_df[melted_df['relevance'] == relevance_value]

    # Create a grid of boxplots for the current 'relevance' value
    plt.figure(figsize=(16, 8))  # Adjust the figure size if needed
    g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=5)
    g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes)

    # Customize plot appearance
    g.set_axis_labels('MDI', 'Value')

    # Customize the legend
    g.add_legend(title='Shrink Mode')

    # Add a title
    plt.suptitle(f'Boxplots of MDI Values by Shrink Mode and Relevance: {relevance_value}', y=1.02)

    # Adjust layout for better spacing
    plt.tight_layout()

    # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
    plt.savefig(f'{relevance_value}.png')

    # Close the plot to free up memory
    plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Iterate through unique 'relevance' values and create diagrams
for relevance_value in melted_df['relevance'].unique():
    # Filter the data for the current 'relevance' value
    subset_df = melted_df[melted_df['relevance'] == relevance_value]

    # Create a grid of boxplots for the current 'relevance' value
    plt.figure(figsize=(16, 8))  # Adjust the figure size if needed
    g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=5)
    g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes)

    # Customize plot appearance
    g.set_axis_labels('MDI', 'Value')

    # Customize the legend
    g.add_legend(title='Shrink Mode')

    # Add a title
    plt.suptitle(f'Boxplots of MDI Values by Shrink Mode and Relevance: {relevance_value}', y=1.02)

    # Show the plot
    plt.show()

    # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
    plt.savefig(f'{relevance_value}.png')

    # Close the plot to free up memory
    plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Define custom x-axis labels
x_labels = [f'x{i}' for i in range(1, 6)]  # Generates 'x1', 'x2', 'x3', 'x4', 'x5'

# Iterate through unique 'relevance' values and create diagrams
for relevance_value in melted_df['relevance'].unique():
    # Filter the data for the current 'relevance' value
    subset_df = melted_df[melted_df['relevance'] == relevance_value]

    # Create a grid of boxplots for the current 'relevance' value
    plt.figure(figsize=(16, 8))  # Adjust the figure size if needed
    g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=5)
    g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes)

    # Customize x-axis labels
    for ax in g.axes.flat:
        ax.set_xticklabels(x_labels)

    # Customize plot appearance
    g.set_axis_labels('MDI', 'Value')

    # Customize the legend
    g.add_legend(title='Shrink Mode')

    # Add a title
    plt.suptitle(f'Boxplots of MDI Values by Shrink Mode and Relevance: {relevance_value}', y=1.02)

    # Show the plot
    plt.show()

    # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
    plt.savefig(f'{relevance_value}.png')

    # Close the plot to free up memory
    plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Define custom x-axis labels with LaTeX formatting
x_labels = ['$X_1$', '$X_2$', '$X_3$', '$X_4$', '$X_5$']

# Iterate through unique 'relevance' values and create diagrams
for relevance_value in melted_df['relevance'].unique():
    # Filter the data for the current 'relevance' value
    subset_df = melted_df[melted_df['relevance'] == relevance_value]

    # Create a grid of boxplots for the current 'relevance' value
    plt.figure(figsize=(16, 8))  # Adjust the figure size if needed
    g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=5)
    g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes)

    # Customize x-axis labels with LaTeX formatting
    for ax in g.axes.flat:
        ax.set_xticklabels(x_labels)

    # Customize plot appearance
    g.set_axis_labels('MDI', 'Value')

    # Customize the legend
    g.add_legend(title='Shrink Mode')

    # Add a title
    plt.suptitle(f'Boxplots of MDI Values by Shrink Mode and Relevance: {relevance_value}', y=1.02)

    # Show the plot
    plt.show()

    # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
    plt.savefig(f'{relevance_value}.png')

    # Close the plot to free up memory
    plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Customize Seaborn style and palette
sns.set(style="whitegrid")

# Define a custom color palette with attractive colors
custom_palette = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd"]

# Assuming you have a DataFrame called df
# Melt the DataFrame to convert it into a long format
melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes = melted_df['shrink_mode'].unique()

# Define custom x-axis labels with LaTeX formatting
x_labels = ['$X_1$', '$X_2$', '$X_3$', '$X_4$', '$X_5$']

# Define the height of the FacetGrid plots (moderately larger)
plot_height = 6

# Iterate through unique 'relevance' values and create attractive diagrams
for relevance_value in melted_df['relevance'].unique():
    # Filter the data for the current 'relevance' value
    subset_df = melted_df[melted_df['relevance'] == relevance_value]

    # Create a grid of boxplots for the current 'relevance' value with a larger height
    plt.figure(figsize=(12, plot_height))  # Adjust the figure size if needed
    g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=plot_height)

    # Customize the color palette with custom colors
    g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes, palette=custom_palette)

    # Customize x-axis labels with LaTeX formatting
    for ax in g.axes.flat:
        ax.set_xticklabels(x_labels)

    # Customize plot appearance
    g.set_axis_labels('MDI', 'Value')
    g.despine(left=True)

    # Customize the legend
    g.add_legend(title='Shrink Mode', loc='upper right', bbox_to_anchor=(1.2, 1))

    # Add a title
    plt.suptitle(f'Boxplots of MDI Values by Shrink Mode and Relevance: {relevance_value}', y=1.02, fontsize=16, fontweight='bold')

    # Show the plot
    plt.show()

    # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
    plt.savefig(f'{relevance_value}_boxplot.png', bbox_inches='tight')

    # Close the plot to free up memory
    plt.close()

# %%
def generate_custom_boxplots(df):
    '''
    Generate custom boxplots based on the provided DataFrame.

    Args:
        df (DataFrame): The input DataFrame containing relevant data.

    Returns:
        Boxplots
    '''
    # Customize Seaborn style and palette
    sns.set(style="whitegrid")

    # Define a custom color palette with attractive colors
    custom_palette = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd"]

    # Melt the DataFrame to convert it into a long format
    melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

    # Get the unique 'shrink_mode' values for the entire DataFrame
    unique_shrink_modes = melted_df['shrink_mode'].unique()

    # Define custom x-axis labels with LaTeX formatting
    x_labels = ['$X_1$', '$X_2$', '$X_3$', '$X_4$', '$X_5$']

    # Define the height of the FacetGrid plots (moderately larger)
    plot_height = 6

    # Iterate through unique 'relevance' values and create attractive diagrams
    for relevance_value in melted_df['relevance'].unique():
        # Filter the data for the current 'relevance' value
        subset_df = melted_df[melted_df['relevance'] == relevance_value]

        # Create a grid of boxplots for the current 'relevance' value with a larger height
        plt.figure(figsize=(12, plot_height))  # Adjust the figure size if needed
        g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=plot_height)

        # Customize the color palette with custom colors
        g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes, palette=custom_palette)

        # Customize x-axis labels with LaTeX formatting
        for ax in g.axes.flat:
            ax.set_xticklabels(x_labels)

        # Customize plot appearance
        g.set_axis_labels('MDI', 'Value')
        g.despine(left=True)

        # Customize the legend
        g.add_legend(title='Shrink Mode', loc='upper right', bbox_to_anchor=(1.2, 1))

        # Set the title to include the relevance number
        ax = g.axes[0, 0]
        ax.set_title(f'Relevance: {relevance_value}')

        # Show the plot
        plt.show()

        # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
        plt.savefig(f'Relevance_{relevance_value}_boxplot.png', bbox_inches='tight')

        # Close the plot to free up memory
        plt.close()

# %%
generate_custom_boxplots(df)

# %% [markdown]
# ###Final Code for submit....

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def generate_custom_boxplots(df):
    '''
    Generate custom boxplots based on the provided DataFrame.

    Args:
        df (DataFrame): The input DataFrame containing relevant data.

    Returns:
        Boxplots
    '''
    # Customize Seaborn style and palette
    sns.set(style="whitegrid")

    # Define a custom color palette with attractive colors
    custom_palette = ["#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#9b59b6"]  # Custom colors

    # Melt the DataFrame to convert it into a long format
    melted_df = pd.melt(df, id_vars=['relevance', 'shrink_mode'], value_vars=['MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'], var_name='MDI', value_name='value')

    # Get the unique 'shrink_mode' values for the entire DataFrame
    unique_shrink_modes = melted_df['shrink_mode'].unique()

    # Define custom x-axis labels with LaTeX formatting
    x_labels = ['$X_1$', '$X_2$', '$X_3$', '$X_4$', '$X_5$']

    # Define the height of the FacetGrid plots (moderately larger)
    plot_height = 6

    # Iterate through unique 'relevance' values and create attractive diagrams
    for relevance_value in melted_df['relevance'].unique():
        # Filter the data for the current 'relevance' value
        subset_df = melted_df[melted_df['relevance'] == relevance_value]

        # Create a grid of boxplots for the current 'relevance' value with a larger height
        plt.figure(figsize=(12, plot_height))  # Adjust the figure size if needed
        g = sns.FacetGrid(data=subset_df, col='relevance', sharey=True, height=plot_height)

        # Customize the color palette with custom colors
        g.map_dataframe(sns.boxplot, x='MDI', y='value', hue='shrink_mode', hue_order=unique_shrink_modes, palette=custom_palette)

        # Customize x-axis labels with LaTeX formatting
        for ax in g.axes.flat:
            ax.set_xticklabels(x_labels)

        # Customize plot appearance
        g.set_axis_labels('MDI', 'Value')
        g.despine(left=True)

        # Customize the legend
        g.add_legend(loc='upper right', bbox_to_anchor=(1.2, 1))

        # Set the title to include the relevance number
        ax = g.axes[0, 0]
        ax.set_title(f'Relevance: {relevance_value}')

        # Show the plot
        plt.show()

        # Save the plot to a file with a relevant filename (e.g., relevance_value.png)
        plt.savefig(f'Relevance_{relevance_value}_boxplot.png', bbox_inches='tight')

        # Close the plot to free up memory
        plt.close()

# Example usage with a DataFrame 'your_df'
# generate_custom_boxplots(your_df)

# %%
generate_custom_boxplots(df)

# %%
generate_custom_boxplots <- function(df) {
    # Load the necessary libraries
    library(ggplot2)
    library(reshape2)

    # Define a custom color palette with attractive colors
    custom_palette <- c("#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#9b59b6")

    # Melt the DataFrame to convert it into a long format
    melted_df <- melt(df, id.vars=c('relevance', 'shrink_mode'),
                      measure.vars=c('MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'),
                      variable.name='MDI', value.name='value')

    # Get the unique 'shrink_mode' values for the entire DataFrame
    unique_shrink_modes <- unique(melted_df$shrink_mode)

    # Define custom x-axis labels with LaTeX mathematical expressions
    x_labels <- c(expression(X[1]), expression(X[2]), expression(X[3]), expression(X[4]), expression(X[5]))

    # Define the height of the FacetGrid plots (moderately larger)
    plot_height <- 6

    # Iterate through unique 'relevance' values and create attractive diagrams
    for (relevance_value in unique(melted_df$relevance)) {
        # Filter the data for the current 'relevance' value
        subset_df <- subset(melted_df, relevance == relevance_value)

        # Create a ggplot object for boxplots
        p <- ggplot(subset_df, aes(x=MDI, y=value, fill=shrink_mode)) +
            geom_boxplot() +
            scale_fill_manual(values=custom_palette) +
            labs(x='MDI', y='Value') +
            theme_minimal() +
            theme(legend.position='right') +  # Change legend position to 'right'
            guides(fill=guide_legend(title='')) +
            scale_x_discrete(labels=x_labels) +
            ggtitle(paste('Relevance:', relevance_value))

        # Print the plot to view it
        print(p)

        # Pause to view the plot before proceeding
        cat("Press Enter to continue...")
        invisible(readLines(""))

        # Save the plot to a file with a relevant filename
        ggsave(filename=paste('Relevance_', relevance_value, '_boxplot.png', sep=''), plot=p, width=12, height=plot_height)
    }
}

# Example usage with your DataFrame 'your_df'
generate_custom_boxplots(df)
