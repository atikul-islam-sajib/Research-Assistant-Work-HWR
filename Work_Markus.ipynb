# 3173 hs_log_cardinality    100    126
# 3174 hs_permutation        100    126
# 3175 hs_global_permutation 100    126
# 3176 hs                      0    127
# 3177 hs_entropy              0    127
# 3178 hs_log_cardinality      0    127
# 3179 hs_permutation         50    127
# 3180 hs_global_permutation   1    127
# 3181 hs                    100    127
# 3182 hs_entropy            100    127
# 3183 hs_log_cardinality    100    127
# 3184 hs_permutation        100    127
# 3185 hs_global_permutation 100    127
# 3186 hs                    100    127
# 3187 hs_entropy            100    127
# 3188 hs_log_cardinality    100    127
# 3189 hs_permutation        100    127
# 3190 hs_global_permutation 100    127
# 3191 hs                    100    127
# 3192 hs_entropy            100    127
# 3193 hs_log_cardinality    100    127
# 3194 hs_permutation        100    127
# 3195 hs_global_permutation 100    127
# 3196 hs                    100    127
# 3197 hs_entropy            100    127
# 3198 hs_log_cardinality    100    127
# 3199 hs_permutation        100    127
# 3200 hs_global_permutation 100    127

# %%
install.packages("reshape2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Load the necessary libraries
library(ggplot2)
library(reshape2)

# Define a custom color palette with attractive colors
custom_palette <- c("#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#9b59b6")

# Melt the DataFrame to convert it into a long format
melted_df <- melt(df, id.vars=c('relevance', 'shrink_mode'),
                  measure.vars=c('MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'),
                  variable.name='MDI', value.name='value')

# Get the unique 'shrink_mode' values for the entire DataFrame
unique_shrink_modes <- unique(melted_df$shrink_mode)

# Define custom x-axis labels
x_labels <- c('$X_1$', '$X_2$', '$X_3$', '$X_4$', '$X_5$')

# Define the height of the FacetGrid plots (moderately larger)
plot_height <- 6

# Iterate through unique 'relevance' values and create attractive diagrams
for (relevance_value in unique(melted_df$relevance)) {
    # Filter the data for the current 'relevance' value
    subset_df <- subset(melted_df, relevance == relevance_value)

    # Create a ggplot object for boxplots
    p <- ggplot(subset_df, aes(x=MDI, y=value, fill=shrink_mode)) +
        geom_boxplot() +
        scale_fill_manual(values=custom_palette) +
        labs(x='MDI', y='Value') +
        theme_minimal() +
        theme(legend.position='top') +
        guides(fill=guide_legend(title='')) +
        scale_x_discrete(labels=x_labels) +
        ggtitle(paste('Relevance:', relevance_value))

    # Print the plot to view it
    print(p)

    # Pause to view the plot before proceeding
    cat("Press Enter to continue...")
    invisible(readLines(""))

    # Save the plot to a file with a relevant filename
    ggsave(filename=paste('Relevance_', relevance_value, '_boxplot.png', sep=''), plot=p, width=12, height=plot_height)
}
# Out:
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# plot without title

# %%
# Load the necessary libraries
library(ggplot2)
library(reshape2)

# Assuming you have a DataFrame 'df'
generate_custom_boxplots(data)
# Out:
# Error in generate_custom_boxplots(data): could not find function "generate_custom_boxplots"
# Traceback:

# %%
generate_custom_boxplots <- function(df) {
    # Load the necessary libraries
    library(ggplot2)
    library(reshape2)

    # Define a custom color palette with attractive colors
    custom_palette <- c("#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#9b59b6")

    # Melt the DataFrame to convert it into a long format
    melted_df <- melt(df, id.vars=c('relevance', 'shrink_mode'),
                      measure.vars=c('MDI_0', 'MDI_1', 'MDI_2', 'MDI_3', 'MDI_4'),
                      variable.name='MDI', value.name='value')

    # Get the unique 'shrink_mode' values for the entire DataFrame
    unique_shrink_modes <- unique(melted_df$shrink_mode)

    # Define custom x-axis labels with LaTeX mathematical expressions
    x_labels <- c(expression(X[1]), expression(X[2]), expression(X[3]), expression(X[4]), expression(X[5]))

    # Define the height of the FacetGrid plots (moderately larger)
    plot_height <- 6

    # Iterate through unique 'relevance' values and create attractive diagrams
    for (relevance_value in unique(melted_df$relevance)) {
        # Filter the data for the current 'relevance' value
        subset_df <- subset(melted_df, relevance == relevance_value)

        # Create a ggplot object for boxplots
        p <- ggplot(subset_df, aes(x=MDI, y=value, fill=shrink_mode)) +
            geom_boxplot() +
            scale_fill_manual(values=custom_palette) +
            labs(x='MDI', y='Value') +
            theme_minimal() +
            theme(legend.position='right') +  # Change legend position to 'right'
            guides(fill=guide_legend(title='')) +
            scale_x_discrete(labels=x_labels) +
            ggtitle(paste('Relevance:', relevance_value))

        # Print the plot to view it
        print(p)

        # Pause to view the plot before proceeding
        cat("Press Enter to continue...")
        invisible(readLines(""))

        # Save the plot to a file with a relevant filename
        ggsave(filename=paste('Relevance_', relevance_value, '_boxplot.png', sep=''), plot=p, width=12, height=plot_height)
    }
}

# Example usage with your DataFrame 'your_df'
generate_custom_boxplots(df)
# Out:
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# Press Enter to continue...
# Warning message in file(con, "r"):
# “file("") only supports open = "w+" and open = "w+b": using the former”
# plot without title
# plot without title
