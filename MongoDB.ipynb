# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.4 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 13.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.8.0

# %%
# !pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.6.1)

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://sajib:sajib@cluster0.ym14neq.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/california_housing_train.csv")

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
documents = df.to_dict(orient="records")

# %%
database = client["california"]

# %%
collection = database["dataset"]

# %%
collection.insert_one(
    {
        "name": "Atikul Islam Sajib",
        "Id": "011142099"
    }
)
# Out:
# InsertOneResult(ObjectId('667f0d877c0ddbe65c47c81f'), acknowledged=True)

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000004c7'), 'opTime': {'ts': Timestamp(1719602596, 41), 't': 1223}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1719602596, 44), 'signature': {'hash': b'\xab)\x97\xddL[k\xa5\x18)\xda\x15\xdc\x88\x8a\xe6\x85Se9', 'keyId': 7327356490652581890}}, 'operationTime': Timestamp(1719602596, 41)}, acknowledged=True)

# %%
collection.insert_many(documents=documents)
# Out:
# InsertManyResult([ObjectId('667f0dbe7c0ddbe65c47c820'), ObjectId('667f0dbe7c0ddbe65c47c821'), ObjectId('667f0dbe7c0ddbe65c47c822'), ObjectId('667f0dbe7c0ddbe65c47c823'), ObjectId('667f0dbe7c0ddbe65c47c824'), ObjectId('667f0dbe7c0ddbe65c47c825'), ObjectId('667f0dbe7c0ddbe65c47c826'), ObjectId('667f0dbe7c0ddbe65c47c827'), ObjectId('667f0dbe7c0ddbe65c47c828'), ObjectId('667f0dbe7c0ddbe65c47c829'), ObjectId('667f0dbe7c0ddbe65c47c82a'), ObjectId('667f0dbe7c0ddbe65c47c82b'), ObjectId('667f0dbe7c0ddbe65c47c82c'), ObjectId('667f0dbe7c0ddbe65c47c82d'), ObjectId('667f0dbe7c0ddbe65c47c82e'), ObjectId('667f0dbe7c0ddbe65c47c82f'), ObjectId('667f0dbe7c0ddbe65c47c830'), ObjectId('667f0dbe7c0ddbe65c47c831'), ObjectId('667f0dbe7c0ddbe65c47c832'), ObjectId('667f0dbe7c0ddbe65c47c833'), ObjectId('667f0dbe7c0ddbe65c47c834'), ObjectId('667f0dbe7c0ddbe65c47c835'), ObjectId('667f0dbe7c0ddbe65c47c836'), ObjectId('667f0dbe7c0ddbe65c47c837'), ObjectId('667f0dbe7c0ddbe65c47c838'), ObjectId('667f0dbe7c0ddbe65c47c839'), ObjectId('667f0dbe7c0ddbe65c47c83a'), ObjectId('667f0dbe7c0ddbe65c47c83b'), ObjectId('667f0dbe7c0ddbe65c47c83c'), ObjectId('667f0dbe7c0ddbe65c47c83d'), ObjectId('667f0dbe7c0ddbe65c47c83e'), ObjectId('667f0dbe7c0ddbe65c47c83f'), ObjectId('667f0dbe7c0ddbe65c47c840'), ObjectId('667f0dbe7c0ddbe65c47c841'), ObjectId('667f0dbe7c0ddbe65c47c842'), ObjectId('667
e65c47c87a'), ObjectId('667f0dbe7c0ddbe65c47c87b'), ObjectId('667f0dbe7c0ddbe65c47c87c'), ObjectId('667f0dbe7c0ddbe65c47c87d'), ObjectId('667f0dbe7c0ddbe65c47c87e'), ObjectId('667f0dbe7c0ddbe65c47c87f'), ObjectId('667f0dbe7c0ddbe65c47c880'), ObjectId('667f0dbe7c0ddbe65c47c881'), ObjectId('667f0dbe7c0ddbe65c47c882'), ObjectId('667f0dbe7c0ddbe65c47c883'), ObjectId('667f0dbe7c0ddbe65c47c884'), ObjectId('667f0dbe7c0ddbe65c47c885'), ObjectId('667f0dbe7c0ddbe65c47c886'), ObjectId('667f0dbe7c0ddbe65c47c887'), ObjectId('667f0dbe7c0ddbe65c47 ...

# %%
cursor = collection.find({})

# %%
cursor

# %%
dataframe = []
for data in cursor:
  dataframe.append(data)
# Out:
# {'_id': ObjectId('667f0dbe7c0ddbe65c47c820'), 'longitude': -114.31, 'latitude': 34.19, 'housing_median_age': 15.0, 'total_rooms': 5612.0, 'total_bedrooms': 1283.0, 'population': 1015.0, 'households': 472.0, 'median_income': 1.4936, 'median_house_value': 66900.0}

# %%
pd.DataFrame(cursor)
# Out:
#                             _id  longitude  latitude  housing_median_age  \
# 0      667f0dbe7c0ddbe65c47c821    -114.47     34.40                19.0
# 1      667f0dbe7c0ddbe65c47c822    -114.56     33.69                17.0
# 2      667f0dbe7c0ddbe65c47c823    -114.57     33.64                14.0
# 3      667f0dbe7c0ddbe65c47c824    -114.57     33.57                20.0
# 4      667f0dbe7c0ddbe65c47c825    -114.58     33.63                29.0
# ...                         ...        ...       ...                 ...
# 16994  667f0dbe7c0ddbe65c480a83    -124.26     40.58                52.0
# 16995  667f0dbe7c0ddbe65c480a84    -124.27     40.69                36.0
# 16996  667f0dbe7c0ddbe65c480a85    -124.30     41.84                17.0
# 16997  667f0dbe7c0ddbe65c480a86    -124.30     41.80                19.0
# 16998  667f0dbe7c0ddbe65c480a87    -124.35     40.54                52.0
#
#        total_rooms  total_bedrooms  population  households  median_income  \
# 0           7650.0          1901.0      1129.0       463.0         1.8200
# 1            720.0           174.0       333.0       117.0         1.6509
# 2           1501.0           337.0       515.0       226.0         3.1917
# 3           1454.0           326.0       624.0       262.0         1.9250
# 4           1387.0           236.0       671.0       239.0         3.3438
# ...            ...             ...         ...         ...            ...
# 16994       2217.0           394.0       907.0       369.0         2.3571
# 16995       2349.0           528.0      1194.0       465.0         2.5179
# 16996       2677.0           531.0      1244.0       456.0         3.0313
# 16997       2672.0           552.0      1298.0       478.0         1.9797
# 16998       1820.0           300.0       806.0       270.0         3.0147
#
#        median_house_value
# 0                 80100.0
# 1                 85700.0
# 2                 73400.0
# 3                 65500.0
# 4                 74000.0
# ...                   ...
# 16994            111400.0
# 16995             79000.0
# 16996            103600.0
# 16997             85800.0
# 16998             94600.0
#
# [16999 rows x 10 columns]
